# %%
from bs4 import BeautifulSoup as bs
import requests
r = requests.get('https://edition.cnn.com/')
soup = bs(r.text, 'lxml')
for link in soup.find_all('a',href=True):
    print(link['href'])
# Out:
# /
# /world
# /politics
# /business
# /health
# /entertainment
# /style
# /travel
# /sport
# /videos
# //us.cnn.com?hpt=header_edition-picker
# //edition.cnn.com?hpt=header_edition-picker
# //arabic.cnn.com?hpt=header_edition-picker
# //cnnespanol.cnn.com?hpt=header_edition-picker
# //us.cnn.com?hpt=header_edition-picker
# //edition.cnn.com?hpt=header_edition-picker
# //arabic.cnn.com?hpt=header_edition-picker
# //cnnespanol.cnn.com?hpt=header_edition-picker
# /world
# /africa
# /americas
# /asia
# /australia
# /china
# /europe
# /india
# /middle-east
# /uk
# /politics
# /specials/politics/joe-biden-news
# /specials/politics/fact-check-politics
# /election/2020/results/president
# /business
# https://money.cnn.com/data/markets/
# /business/tech
# /business/media
# /business/success
# /business/perspectives
# /business/videos
# /health
# /specials/health/food-diet
# /specials/health/fitness-excercise
# /specials/health/wellness
# /specials/health/parenting
# /specials/health/vital-signs
# /entertainment
# /entertainment/celebrities
# /entertainment/movies
# /entertainment/tv-shows
# /entertainment/culture
# /business/media
# /business/tech
# /specials/tech/innovate
# /specials/tech/gadget
# /specials/tech/foreseeable-future
# /specials/tech/mission-ahead
# /specials/tech/upstarts
# /specials/tech/work-transformed
# /specials/tech/innovative-cities
# /style
# /style/arts
# /style/design
# /style/fashion
# /style/architecture
# /style/luxury
# /style/beauty
# /style/videos
# /travel
# /travel/destinations
# /travel/food-and-drink
# /travel/stay
# /travel/news
# /travel/videos
# /sport
# /sport/football
# /sport/tennis
# /sport/golf
# /sport/olympics
# /specials/sport/us-sports
# /specials/climbing
# /sport/motorsport
# /specials/sport/formula-e
# /specials/esports
# /videos
# //cnn.it/go2
# /specials/digital-studios
# /specials/videos/digital-shorts
# /specials/videos/hln
# /tv/schedule/cnn
# /specials/tv/all-shows
# /vr
# /specials
# /interactive/asequals/
# /interactive/call-to-earth/
# /specials/world/freedom-project
# /specials/impact-your-world
# /specials/africa/inside-africa
# /specials/opinions/two-degrees
# /specials/cnn-heroes
# /specials
# /weather
# /specials/world/cnn-climate
# /interactive/2020/weather/gonzalo-storm-path-tracker/index.html
# /interactive/2020/weather/wildfire-and-air-quality-tracker/
# /specials/weather/weather-video
# /more
# /specials/photos
# /specials/cnn-longform
# /specials/cnn-investigates
# /specials/profiles
# /specials/more/cnn-leadership
# /email/subscription
# https://www.turnerjobs.com/search-jobs?orgIds=1174&ac=19299
# //facebook.com/cnninternational
# //twitter.com/cnni
# //instagram.com/cnn
# /world
# /africa
# /americas
# /asia
# /australia
# /china
# /europe
# /india
# /middle-east
# /uk
# /politics
# /specials/politics/joe-biden-news
# /specials/politics/fact-check-politics
# /election/2020/results/president
# /business
# https://money.cnn.com/data/markets/
# /business/tech
# /business/media
# /business/success
# /business/perspectives
# /business/videos
# /health
# /specials/health/food-diet
# /specials/health/fitness-excercise
# /specials/health/wellness
# /specials/health/parenting
# /specials/health/vital-signs
# /entertainment
# /entertainment/celebrities
# /entertainment/movies
# /entertainment/tv-shows
# /entertainment/culture
# /business/media
# /business/tech
# /specials/tech/innovate
# /specials/tech/gadget
# /specials/tech/foreseeable-future
# /specials/tech/mission-ahead
# /specials/tech/upstarts
# /specials/tech/work-transformed
# /specials/tech/innovative-cities
# /style
# /style/arts
# /style/design
# /style/fashion
# /style/architecture
# /style/luxury
# /style/beauty
# /style/videos
# /travel
# /travel/destinations
# /travel/food-and-drink
# /travel/stay
# /travel/news
# /travel/videos
# /sport
# /sport/football
# /sport/tennis
# /sport/golf
# /sport/olympics
# /specials/sport/us-sports
# /specials/climbing
# /sport/motorsport
# /specials/sport/formula-e
# /specials/esports
# /videos
# //cnn.it/go2
# /specials/digital-studios
# /specials/videos/digital-shorts
# /specials/videos/hln
# /tv/schedule/cnn
# /specials/tv/all-shows
# /vr
# /specials
# /interactive/asequals/
# /interactive/call-to-earth/
# /specials/world/freedom-project
# /specials/impact-your-world
# /specials/africa/inside-africa
# /specials/opinions/two-degrees
# /specials/cnn-heroes
# /specials
# /weather
# /specials/world/cnn-climate
# /interactive/2020/weather/gonzalo-storm-path-tracker/index.html
# /interactive/2020/weather/wildfire-and-air-quality-tracker/
# /specials/weather/weather-video
# /more
# /specials/photos
# /specials/cnn-longform
# /specials/cnn-investigates
# /specials/profiles
# /specials/more/cnn-leadership
# /email/subscription
# https://www.turnerjobs.com/search-jobs?orgIds=1174&ac=19299
# /
# //facebook.com/cnninternational
# //twitter.com/cnni
# //instagram.com/cnn
# /terms
# /privacy
# /accessibility
# #
# /about
# /msa
# https://commercial.cnn.com
# //store.cnn.com
# /newsletters
# /transcripts
# /collection
# http://cnnnewsource.com
# https://www.cnn.com/sitemap.html
